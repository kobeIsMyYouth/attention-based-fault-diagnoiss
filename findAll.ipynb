# %%
import numpy as np
import re

# %%
f = open("./results/TE chemical process/res_12_1_5/strsources.txt", encoding='utf-8')
test_accs = []
lines = f.readline()
while lines:
    if lines.startswith("测试准确率为"):
        print(lines)
        test_accs.append(float(lines[7:14]))
    lines = f.readline()
f.close()
# Out:
# 测试准确率为 31.3506%
#
# 测试准确率为 43.3812%
#
# 测试准确率为 50.4981%
#
# 测试准确率为 55.6418%
#
# 测试准确率为 60.6226%
#
# 测试准确率为 64.7414%
#
# 测试准确率为 67.7395%
#
# 测试准确率为 69.7126%
#
# 测试准确率为 71.5421%
#
# 测试准确率为 72.9023%
#
# 测试准确率为 74.6552%
#
# 测试准确率为 75.9770%
#
# 测试准确率为 76.2548%
#
# 测试准确率为 77.0019%
#
# 测试准确率为 78.7356%
#
# 测试准确率为 79.9234%
#
# 测试准确率为 80.8429%
#
# 测试准确率为 81.3985%
#
# 测试准确率为 82.1073%
#
# 测试准确率为 83.2375%
#
# 测试准确率为 83.1034%
#
# 测试准确率为 83.0460%
#
# 测试准确率为 83.8410%
#
# 测试准确率为 84.2625%
#
# 测试准确率为 85.0670%
#
# 测试准确率为 85.2203%
#
# 测试准确率为 85.2299%
#
# 测试准确率为 85.3065%
#
# 测试准确率为 85.5939%
#
# 测试准确率为 85.1820%
#
# 测试准确率为 85.6513%
#
# 测试准确率为 85.6418%
#
# 测试准确率为 87.4042%
#
# 测试准确率为 87.3851%
#
# 测试准确率为 86.6954%
#
# 测试准确率为 88.2088%
#
# 测试准确率为 88.9464%
#
# 测试准确率为 88.2088%
#
# 测试准确率为 88.1034%
#
# 测试准确率为 88.2663%
#
# 测试准确率为 88.4866%
#
# 测试准确率为 88.9368%
#
# 测试准确率为 88.1418%
#
# 测试准确率为 89.2241%
#
# 测试准确率为 89.7510%
#
# 测试准确率为 90.9387%
#
# 测试准确率为 89.7893%
#
# 测试准确率为 88.5249%
#
# 测试准确率为 89.3582%
#
# 测试准确率为 90.0383%
#
# ...

# %%
print(test_accs)
# Out:
# [31.3506, 43.3812, 50.4981, 55.6418, 60.6226, 64.7414, 67.7395, 69.7126, 71.5421, 72.9023, 74.6552, 75.977, 76.2548, 77.0019, 78.7356, 79.9234, 80.8429, 81.3985, 82.1073, 83.2375, 83.1034, 83.046, 83.841, 84.2625, 85.067, 85.2203, 85.2299, 85.3065, 85.5939, 85.182, 85.6513, 85.6418, 87.4042, 87.3851, 86.6954, 88.2088, 88.9464, 88.2088, 88.1034, 88.2663, 88.4866, 88.9368, 88.1418, 89.2241, 89.751, 90.9387, 89.7893, 88.5249, 89.3582, 90.0383, 90.6513, 90.5651, 89.5307, 91.1015, 91.1494, 91.4943, 90.546, 91.092, 91.3314, 90.6418, 89.9617, 91.6571, 91.705, 91.5134, 92.0019, 91.772, 92.0307, 92.0785, 91.2261, 91.8295, 92.2222, 90.4789, 91.2644, 92.1743, 91.1973, 92.5862, 91.4559, 90.7375, 92.4425, 92.5862, 91.9349, 92.2797, 91.3602, 92.7203, 92.136, 92.4234, 92.2605, 92.8257, 92.7011, 92.3372, 92.567, 92.749, 92.8927, 92.1552, 91.3506, 92.4138, 91.2069, 93.1609, 93.1034, 92.5479]

# %%
import numpy as np

# %%
np.savetxt("./results/TE chemical process/res_12_1_5/test_accs.txt", np.array(test_accs) / 100)
